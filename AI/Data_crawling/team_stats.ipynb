# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

# 요청에 필요한 데이터 설정
url = 'https://statiz.sporki.com/stats/?m=team&m2=batting&m3=default&so=WAR&ob=DESC&year=2024&sy=2019&ey=2024&te=&po=&lt=10100&reg=&pe=&ds=&de=&we=&hr=&ha=&ct=&st=&vp=&bo=&pt=&pp=&ii=&vc=&um=&oo=&rr=&sc=&bc=&ba=&li=&as=&ae=&pl=&gc=&lr=&pr=50&ph=&hs=&us=&na=&ls=&sf1=&sk1=&sv1=&sf2=&sk2=&sv2='
headers = {'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/124.0.0.0 Safari/537.36'}

response = requests.post(url, headers=headers)  # 또는 requests.get() 사용

res = requests.get(url, headers=headers)
res.raise_for_status()

html = response.text

# 응답에서 데이터 추출
soup = BeautifulSoup(html, "html.parser")

rows = []
data = []

trs = soup.find_all("tr")

for tr in trs[2:]:
    tds = tr.find_all("td")
    tds = [td.text for td in tds]
    rows.append(tds)

# print(rows[0])

for row in rows:
    temp = []
    for index in range(1, len(row)-1):
        temp.append(row[index])
    data.append(temp)

# %%
pd.reset_option('display.max_rows')
pd.reset_option('display.max_columns')
pd.reset_option('display.width')
pd.reset_option('display.max_colwidth')

team_hitter_df = pd.DataFrame(data, columns=['팀', '시즌', 'WAR', '공격WAR', '수비WAR', '게임수', '타석', '유효타석', '타수', '득점', '안타', '2루타', '3루타', '홈런', '루타', '타점', '도루성공', '도루실패', '4구', '사구', '고의사구', '피삼진', '피병살타', '희생타', '희생플라이', '타율', '출루율', '장타율', 'OPS', 'R/ePA', '득점 창출력'])

team_hitter_df
# Out:
#       팀  시즌     WAR   공격WAR  수비WAR    게임수     타석   유효타석     타수    득점  ...  \
# 0    리그  22  246.20  246.20   0.01  17841  55963  55206  49276  6523  ...
# 1    리그  19  246.18  246.25  -0.07  17618  55627  55099  49225  6548  ...
# 2    리그  20  245.60  245.60   0.00  18815  56643  56060  49658  7436  ...
# 3    리그  23  243.67  243.67   0.00  18236  56231  55462  49236  6622  ...
# 4    리그  21  242.76  242.76   0.00  18536  56076  55470  48402  6896  ...
# ..  ...  ..     ...     ...    ...    ...    ...    ...    ...   ...  ...
# 63   한화  24    6.19    6.65  -0.46    568   1863   1848   1617   236  ...
# 64   한화  20    5.73    6.12  -0.39   1886   5483   5430   4862   551  ...
# 65   롯데  19    5.29   11.08  -5.79   1823   5488   5446   4919   578  ...
# 66   키움  24    5.20    5.73  -0.53    539   1806   1792   1599   219  ...
# 67   롯데  24    3.70    5.46  -1.76    586   1771   1761   1590   202  ...
#
#        삼진   병살타  희생타 희생플라이     타율    출루율    장타율    OPS  R/ePA 득점 창출력
# ...

# %%
# 요청에 필요한 데이터 설정
url = 'https://statiz.sporki.com/stats/?m=team&m2=pitching&m3=default&so=WAR&ob=DESC&year=2024&sy=2019&ey=2024&te=&po=&lt=10100&reg=&pe=&ds=&de=&we=&hr=&ha=&ct=&st=&vp=&bo=&pt=&pp=&ii=&vc=&um=&oo=&rr=&sc=&bc=&ba=&li=&as=&ae=&pl=&gc=&lr=&pr=50&ph=&hs=&us=&na=&ls=&sf1=&sk1=&sv1=&sf2=&sk2=&sv2='

response = requests.post(url, headers=headers)  # 또는 requests.get() 사용

res = requests.get(url, headers=headers)
res.raise_for_status()

html = response.text

# 응답에서 데이터 추출
soup = BeautifulSoup(html, "html.parser")

rows = []
data = []

trs = soup.find_all("tr")

for tr in trs[2:]:
    tds = tr.find_all("td")
    tds = [td.text for td in tds]
    rows.append(tds)

# print(rows[0])

for row in rows:
    temp = []
    for index in range(1, len(row)-1):
        temp.append(row[index])
    data.append(temp)

# %%
team_pitcher_df = pd.DataFrame(data, columns=['팀', '시즌', 'WAR', '출장 경기', '선발 출장', '불펜 출장', '마무리 출장', '완투', '완봉', '승', '패', '세이브', '홀드', '이닝', '자책점', '실점', '책임 실점', '상대타자 수', '피안타', '피2루타', '피3루타', '피홈런', '볼넷 허용', '사구 허용', '고의4구 허용', '삼진', '실책 출루 허용', '보크', '폭투', '평균 자책점', '9이닝당 실점', '9이닝당 책임실점', '수비 무관 평균자책점', '이닝당 출루허용률'])

team_pitcher_df
# Out:
#        팀  시즌     WAR 출장 경기 선발 출장 불펜 출장 마무리 출장  완투  완봉    승  ... 고의4구 허용  \
# 0     리그  21  216.24  6755  1438  5317   1440  13   7  670  ...     180
# 1     리그  20  210.33  6857  1440  5417   1440  10   5  707  ...     163
# 2     리그  22  209.64  6719  1440  5279   1440   6   3  708  ...     208
# 3     리그  19  205.86  6215  1440  4775   1440  23  12  713  ...     147
# 4     리그  23  204.13  6845  1440  5405   1440   5   0  708  ...     175
# ..   ...  ..     ...   ...   ...   ...    ...  ..  ..  ...  ...     ...
# 63    LG  24    7.71   242    49   193     49   0   0   25  ...       5
# 64    키움  24    7.43   210    46   164     46   0   0   19  ...       4
# 65    한화  24    6.23   244    47   197     47   0   0   18  ...       4
# 66   SSG  24    5.10   237    48   189     48   0   0   25  ...       8
# 67    KT  24    4.66   224    48   176     48   0   0   19  ...       5
#
#        삼진 실책 출루 허용  보크   폭투 평균 자책점 9이닝당 실점 9이닝당 책임실점 수비 무관 평균자책점 이닝당 출루허용률
# ...

# %%
url = 'https://statiz.sporki.com/stats/?m=team&m2=fielding&m3=default&so=WAAwithPOS&ob=DESC&year=2024&sy=2019&ey=2024&te=&po=&lt=&reg=&pe=&ds=&de=&we=&hr=&ha=&ct=&st=&vp=&bo=&pt=&pp=&ii=&vc=&um=&oo=&rr=&sc=&bc=&ba=&li=&as=&ae=&pl=&gc=&lr=&pr=50&ph=&hs=&us=&na=&ls=&sf1=&sk1=&sv1=&sf2=&sk2=&sv2='

response = requests.post(url, headers=headers)  # 또는 requests.get() 사용

res = requests.get(url, headers=headers)
res.raise_for_status()

html = response.text

# 응답에서 데이터 추출
soup = BeautifulSoup(html, "html.parser")

rows = []
data = []

trs = soup.find_all("tr")

for tr in trs[2:]:
    tds = tr.find_all("td")
    tds = [td.text for td in tds]
    rows.append(tds)

for row in rows:
    temp = []
    for index in range(1, len(row)-1):
        temp.append(row[index])
    data.append(temp)

# %%
team_defense_df = pd.DataFrame(data, columns=['팀', '시즌', '평균 대비 수비 승리 기여도', '출장 경기', '선발 출장', '이닝', '수비 기회', '자살', '보살', '실책', '수비율', '9이닝당 레인지 팩터', '범위 득점 기여', '외야 득점 기여', '실책 득점 기여', '병살 득점 기여', '번트 득점 기여', '도루 저지 득점 기여', '블로킹 득점 기여', '프레이밍 득점 기여', '평균 대비 수비 득점 기여', '/144', '포지션 조정', '포지션 조정 평균 대비 수비 득점 기여', '평균 대비 수비 득점 기여'])

team_defense_df
# Out:
#        팀  시즌 평균 대비 수비 승리 기여도  출장 경기  선발 출장        이닝  수비 기회     자살     보살  \
# 0     리그  24          -2.530   6346   4283   38560.1  16814  12503   3988
# 1     리그  20          -7.199  21752  13391  120199.1  51890  38006  12999
# 2     리그  19          -8.073  19956  13282  118991.2  52203  37872  13427
# 3     리그  23          -8.164  20608  13087  118679.2  51584  38076  12502
# 4     리그  22          -8.228  20422  13260  119772.0  52212  38089  13100
# ..   ...  ..             ...    ...    ...       ...    ...    ...    ...
# 63    키움  23          -5.646   2201   1338   12235.1   5280   3835   1335
# 64    롯데  19          -6.516   2110   1332   11943.0   5229   3765   1351
# 65   KIA  19          -6.523   2108   1331   11828.1   5136   3748   1285
# 66    롯데  22          -7.510   1964   1309   11807.2   5158   3778   1277
# 67   KIA  20          -8.392   1846   1378   11939.1   5259   3776   1397
#
#       실책  ... 병살 득점 기여 번트 득점 기여 도루 저지 득점 기여 블로킹 득점 기여 프레이밍 득점 기여  \
# ...

# %%
url = 'https://statiz.sporki.com/stats/?m=team&m2=all&m3=default&so=WAR&ob=DESC&year=2024&sy=2019&ey=2024&te=&po=&lt=&reg=&pe=&ds=&de=&we=&hr=&ha=&ct=&st=&vp=&bo=&pt=&pp=&ii=&vc=&um=&oo=&rr=&sc=&bc=&ba=&li=&as=&ae=&pl=&gc=&lr=&pr=50&ph=&hs=&us=&na=&ls=&sf1=&sk1=&sv1=&sf2=&sk2=&sv2='

response = requests.post(url, headers=headers)  # 또는 requests.get() 사용

res = requests.get(url, headers=headers)
res.raise_for_status()

html = response.text

# 응답에서 데이터 추출
soup = BeautifulSoup(html, "html.parser")

rows = []
data = []

trs = soup.find_all("tr")

for tr in trs[2:]:
    tds = tr.find_all("td")
    tds = [td.text for td in tds]
    rows.append(tds)

for row in rows:
    temp = []
    for index in range(1, len(row)-1):
        temp.append(row[index])
    data.append(temp)

# %%
team_total_df = pd.DataFrame(data, columns=['팀', '시즌', 'WAR', '평균 대비 타격 승리 기여도', '평균 대비 도루 승리 기여도', '평균 대비 주루 승리 기여도', '평균 대비 수비 승리 기여도', '대체 승리', '대체 포지션 조정', '평균 대비 선발 승리 기여도', '평균 대비 불펜 승리 기여도', '선발 대체 승리', '불펜 대체 승리', '선발 WAR', '불펜 WAR'])

team_total_df
# Out:
#        팀  시즌     WAR 평균 대비 타격 승리 기여도 평균 대비 도루 승리 기여도 평균 대비 주루 승리 기여도  \
# 0     리그  21  459.00          459.00           -0.04            0.00
# 1     리그  20  455.93          455.93            0.02            0.00
# 2     리그  22  455.84          455.84            0.01            0.00
# 3     리그  19  452.04          452.04           -0.01            0.00
# 4     리그  23  447.79          447.79            0.10            0.00
# ..   ...  ..     ...             ...             ...             ...
# 63    KT  24   13.45           13.45            0.95           -0.07
# 64    롯데  24   12.70           12.70           -2.48            0.05
# 65    키움  24   12.63           12.63           -1.91           -0.19
# 66    한화  24   12.42           12.42           -0.70           -0.36
# 67   SSG  24   12.06           12.06           -2.46            0.05
#
#    평균 대비 수비 승리 기여도  대체 승리 대체 포지션 조정 평균 대비 선발 승리 기여도 평균 대비 불펜 승리 기여도 선발 대체 승리  \
# ...

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

headers = {'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/124.0.0.0 Safari/537.36'}
data = []

for year in range(2019, 2025):
    url = f'https://statiz.sporki.com/season/?m=teamoverall&year={year}'

    response = requests.post(url, headers=headers)  # 또는 requests.get() 사용

    res = requests.get(url, headers=headers)
    res.raise_for_status()

    html = response.text

    # 응답에서 데이터 추출
    soup = BeautifulSoup(html, "html.parser")

    if year == 2024:
        items = soup.select_one(".table_type03")
        trs = items.find_all("tr")

        rows = []

        for tr in trs[1:]:
            tds = tr.find_all("td")
            tds = [td.text for td in tds]
            rows.append(tds)

        for row in rows:
            temp = []
            for index in range(0, len(row)):
                temp.append(row[index])
            temp.insert(2, year)
            data.append(temp)
    else:
        items = soup.select(".table_type03")
        items = items[1]
        trs = items.find_all("tr")

        rows = []

        for tr in trs[1:]:
            tds = tr.find_all("td")
            tds = [td.text for td in tds]
            rows.append(tds)

        for row in rows:
            temp = []
            for index in range(0, len(row)):
                temp.append(row[index])
            temp.insert(2, year)
            data.append(temp)

# %%
team_rank_df = pd.DataFrame(data, columns=['순위', '팀', '연도', '게임수', '승', '무', '패', '승차', '승률'])

team_rank_df
# Out:
#     순위     팀    연도  게임수   승   무   패    승차     승률
# 0    1    SK  2019  144  88   1  55   0.0  0.615
# 1    1    두산  2019  144  88   1  55   0.0  0.615
# 2    3    키움  2019  144  86   1  57   2.0  0.601
# 3    4    LG  2019  144  79   1  64   9.0  0.552
# 4    5    NC  2019  144  73   2  69  14.5  0.514
# 5    6    KT  2019  144  71   2  71  16.5  0.500
# 6    7   KIA  2019  144  62   2  80  25.5  0.437
# 7    8    삼성  2019  144  60   1  83  28.0  0.420
# 8    9    한화  2019  144  58   0  86  30.5  0.403
# 9   10    롯데  2019  144  48   3  93  39.0  0.340
# 10   1    NC  2020  144  83   6  55   0.0  0.601
# 11   2    KT  2020  144  81   1  62   4.5  0.566
# 12   3    LG  2020  144  79   4  61   5.0  0.564
# 13   3    두산  2020  144  79   4  61   5.0  0.564
# 14   5    키움  2020  144  80   1  63   5.5  0.559
# 15   6   KIA  2020  144  73   0  71  13.0  0.507
# 16   7    롯데  2020  144  71   1  72  14.5  0.497
# 17   8    삼성  2020  144  64   5  75  19.5  0.460
# ...
