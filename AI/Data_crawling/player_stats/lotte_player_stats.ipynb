# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

# 요청에 필요한 데이터 설정
url = 'https://statiz.sporki.com/stats/?m=main&m2=batting&m3=default&so=WAR&ob=DESC&year=2024&sy=2019&ey=2024&te=3&po=&lt=10100&reg=C5&pe=&ds=&de=&we=&hr=&ha=&ct=&st=&vp=&bo=&pt=&pp=&ii=&vc=&um=&oo=&rr=&sc=&bc=&ba=&li=&as=&ae=&pl=&gc=&lr=&pr=1000&ph=&hs=&us=&na=&ls=0&sf1=WAROff&sk1=&sv1=&sf2=WAROff&sk2=&sv2='
headers = {'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/124.0.0.0 Safari/537.36'}

response = requests.post(url, headers=headers)  # 또는 requests.get() 사용

res = requests.get(url, headers=headers)
res.raise_for_status()

html = response.text

# 응답에서 데이터 추출
soup = BeautifulSoup(html, "html.parser")

# print(soup)

rows = []
data = []

trs = soup.find_all("tr")

for tr in trs[2:]:
    tds = tr.find_all("td")
    tds = [td.text for td in tds]
    rows.append(tds)

for row in rows:
    temp = []
    for index in range(1, len(row)-1):
        if index == 2:
            season = row[index][:2]
            position = row[index][3:]
            temp.append(season)
            temp.append(position)
        else:
            temp.append(row[index])
    data.append(temp)

# %%
pd.set_option("display.max_rows", None)
pd.set_option("display.max_columns", None)
pd.set_option("display.max_colwidth", None)

lotte_hitter_df = pd.DataFrame(data, columns=['이름', '연도', '포지션', 'WAR', 'oWAR', 'dWAR', 'G', 'PA', 'ePA', 'AB', 'R', 'H', '2B', '3B', 'HR', 'TB', 'RBI', 'SB', 'CS', 'BB', 'HP', 'IB', 'SO', 'GDP', 'SH', 'SF', 'AVG', 'OBP', 'SLG', 'OPS', 'R/ePA', 'WRC+'])

lotte_hitter_df = lotte_hitter_df.dropna(axis=0)

lotte_hitter_df
# Out:
#        이름  연도  포지션    WAR   oWAR   dWAR    G   PA  ePA   AB   R    H  2B 3B  \
# 0     손아섭  20   RF   5.49   5.78  -0.29  141  611  608  540  98  190  43  0
# 1     마차도  20   SS   4.53   3.09   1.43  144  560  554  486  79  136  31  1
# 2     마차도  21   SS   4.24   2.26   1.99  134  539  535  466  83  130  21  1
# 3     유강남  23    C   4.09   1.90   2.20  121  403  401  352  45   92  13  0
# 4     전준우  21   LF   3.84   5.27  -1.43  144  619  618  552  88  192  46  0
# 5     전준우  23   DH   3.79   5.25  -1.46  138  559  556  493  80  154  21  3
# 6     이대호  22   DH   3.68   5.72  -2.04  142  591  585  540  53  179  23  0
# 7     손아섭  19   RF   3.45   3.23   0.22  134  568  566  512  78  151  22  1
# 8     전준우  20   LF   3.27   3.61  -0.34  143  628  625  562  95  157  34  1
# 9      정훈  21   1B   3.11   3.75  -0.64  135  561  553  486  70  142  27  1
# 12    안치홍  21   2B   2.94   3.67  -0.73  119  490  484  421  58  129  30  2
# ...

# %%
# 요청에 필요한 데이터 설정
url = 'https://statiz.sporki.com/stats/?m=main&m2=pitching&m3=default&so=WAR&ob=DESC&year=2024&sy=2019&ey=2024&te=3001&po=&lt=10100&reg=C3&pe=&ds=&de=&we=&hr=&ha=&ct=&st=&vp=&bo=&pt=&pp=&ii=&vc=&um=&oo=&rr=&sc=&bc=&ba=&li=&as=&ae=&pl=&gc=&lr=&pr=50&ph=&hs=&us=&na=&ls=&sf1=&sk1=&sv1=&sf2=&sk2=&sv2='

response = requests.post(url, headers=headers)  # 또는 requests.get() 사용

res = requests.get(url, headers=headers)
res.raise_for_status()

html = response.text

# 응답에서 데이터 추출
soup = BeautifulSoup(html, "html.parser")

# print(soup)

rows = []
data = []

trs = soup.find_all("tr")

for tr in trs[2:]:
    tds = tr.find_all("td")
    tds = [td.text for td in tds]
    rows.append(tds)

for row in rows:
    temp = []
    for index in range(1, len(row)-1):
        if index == 2:
            season = row[index][:2]
            position = row[index][3:]
            temp.append(season)
            temp.append(position)
        else:
            temp.append(row[index])
    data.append(temp)

# %%
lotte_pitcher_df = pd.DataFrame(data, columns=['이름', '연도', '포지션', 'WAR', 'G', 'GS', 'GR', 'GF', 'CG', 'SHO', 'W', 'L', 'S', 'HD', 'IP', 'ER', 'R', 'rRA', 'TBF', 'H', '2B', '3B', 'HR', 'BB', 'HP', 'IB', 'SO', 'ROE', 'BK', 'WP', 'ERA', 'RA9', 'rRA9', 'rRA9pf', 'FIP', 'WHIP'])

lotte_pitcher_df = lotte_pitcher_df.dropna(axis=0)

lotte_pitcher_df
# Out:
#        이름  연도 포지션   WAR   G  GS  GR  GF CG SHO   W   L   S  HD     IP  ER   R  \
# 0   스트레일리  20   P  8.18  31  31   0   0  0   0  15   4   0   0  194.2  54  61
# 1      반즈  23   P  5.74  30  30   0   0  0   0  11  10   0   0  170.1  62  68
# 2      반즈  22   P  5.70  31  31   0   0  0   0  12  12   0   0  186.1  75  87
# 3     박세웅  21   P  5.23  28  28   0   1  1   1  10   9   0   0  163.0  72  75
# 4     레일리  19   P  5.16  30  30   0   0  0   0   5  14   0   0  181.0  78  88
# 5     박세웅  23   P  4.63  27  27   0   0  0   0   9   7   0   0  154.0  59  70
# 6   스트레일리  21   P  4.37  31  31   0   0  0   0  10  12   0   0  165.2  75  85
# 7     박세웅  22   P  3.97  28  28   0   0  0   0  10  11   0   0  157.1  68  80
# 8     이인복  22   P  3.48  26  23   3   0  0   0   9   9   0   1  126.2  59  63
# 9     나균안  23   P  3.40  23  23   0   0  0   0   6   8   0   0  130.1  55  61
# 12    윌커슨  23   P  3.03  13  13   0   0  0   0   7   2   0   0   79.2  20  28
# ...

# %%
# 요청에 필요한 데이터 설정
url = 'https://statiz.sporki.com/stats/?m=main&m2=fielding&m3=default&so=WAAwithPOS&ob=DESC&year=2024&sy=2019&ey=2024&te=3001&po=&lt=10100&reg=A&pe=&ds=&de=&we=&hr=&ha=&ct=&st=&vp=&bo=&pt=&pp=&ii=&vc=&um=&oo=&rr=&sc=&bc=&ba=&li=&as=&ae=&pl=&gc=&lr=&pr=50&ph=&hs=&us=&na=&ls=&sf1=&sk1=&sv1=&sf2=&sk2=&sv2='

response = requests.post(url, headers=headers)  # 또는 requests.get() 사용

res = requests.get(url, headers=headers)
res.raise_for_status()

html = response.text

# 응답에서 데이터 추출
soup = BeautifulSoup(html, "html.parser")

# print(soup)

rows = []
data = []

trs = soup.find_all("tr")

for tr in trs[2:]:
    tds = tr.find_all("td")
    tds = [td.text for td in tds]
    rows.append(tds)

for row in rows:
    temp = []
    for index in range(1, len(row)-1):
        if index == 2:
            season = row[index][:2]
            position = row[index][3:]
            temp.append(season)
            temp.append(position)
        else:
            temp.append(row[index])
    data.append(temp)

# %%
lotte_defense_df = pd.DataFrame(data, columns=['이름', '연도', '포지션', 'WAAwithPOS', 'G', 'GS', 'IP', 'TC', 'PO', 'Ass', 'E', 'F%', 'RF9', 'Range RAA', 'Arm RAA', 'Err RAA', 'DP RAA', 'Bt RAA', 'CS RAA', 'Blk RAA', 'Frm RAA', 'Total RAA', '/144', 'POSAdj', 'RAAwithPOS', 'WAAwoPOS'])

lotte_defense_df = lotte_defense_df.dropna(axis=0)

lotte_defense_df
# Out:
#       이름  연도  포지션 WAAwithPOS    G   GS      IP   TC   PO  Ass   E     F%  \
# 0    유강남  23    C      2.560  109   98   821.0  778  714   60   4   99.5
# 1    마차도  21   SS      1.977  133  127  1076.2  583  235  337  11   98.1
# 2    마차도  20   SS      1.800  144  139  1180.2  618  228  380  10   98.4
# 3    김준태  20    C      1.301  125   84   793.0  676  615   54   7   99.0
# 4    안중열  21    C      1.017   56   41   364.2  324  292   31   1   99.7
# 5    정보근  22    C      0.958   94   67   585.2  641  592   43   6   99.1
# 6    지시완  21    C      0.864   72   52   448.1  436  395   40   1   99.8
# 7    김준태  21    C      0.716   45   31   286.0  273  254   18   1   99.6
# 8    정보근  23    C      0.673   51   23   228.2  216  191   24   1   99.5
# 9    한동희  20   3B      0.586  124  119   973.0  280   58  206  16   94.3
# 12   신본기  19   SS      0.572  118  108   906.2  448  161  272  15   96.7
# 13   노진혁  23   SS      0.559  107   95   827.0  373  142  220  11   97.1
# ...
