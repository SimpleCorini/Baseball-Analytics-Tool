# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
import re

# %%
team_codes = [6002, 10001, 9001, 5002, 11001, 12001, 2002, 1001, 7002, 3001, 9002]  # 두산, 키움, SK(19~20), LG, NC, KT, KIA, 삼성, 한화, 롯데, SSG(21~)
hitter_pitcher_dict = {}  # 전체 선수 ID와 이름을 저장할 딕셔너리

for team_code in team_codes:
    for year in range(2019, 2025):
        if year > 2020 and team_code == 9001:
            continue

        # 요청에 필요한 데이터 설정
        url = f'https://statiz.sporki.com/team/?m=seasonBacknumber&t_code={team_code}&year={year}'
        headers = {'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/124.0.0.0 Safari/537.36'}

        response = requests.get(url, headers=headers)
        response.raise_for_status()

        html = response.text

        # 응답에서 데이터 추출
        soup = BeautifulSoup(html, "html.parser")

        for link in soup.find_all('a'):
            if '/player/?m=playerinfo&amp;p_no=' in str(link):
                player_no = re.search(r'\d+', str(link)).group()
                player_no = int(player_no)
                player_name = link.text
                hitter_pitcher_dict[player_no] = player_name

print(hitter_pitcher_dict)
# Out:
# {12985: '정기훈', 11094: '함덕주', 11097: '장승현', 14172: '송승환', 13079: '권민석', 11492: '신성현', 12604: '황경태', 12523: '서예일', 13073: '전민재', 13927: '페르난데스', 10891: '박세혁', 10677: '이현호', 10184: '허경민', 12894: '이유찬', 10172: '국해성', 10202: '김승회', 10894: '류지혁', 11491: '박소준', 10351: '권혁', 13061: '곽빈', 10883: '강동연', 10645: '정진호', 10178: '오재원', 10362: '배영수', 10741: '이정담', 13075: '이승민', 10690: '김강률', 10299: '장원준', 10213: '유희관', 10302: '최대성', 10195: '정수빈', 10643: '김재환', 10764: '김도현', 11393: '린드블럼', 10756: '정병곤', 10400: '오재일', 10189: '박건우', 14170: '김대한', 11098: '김인태', 13070: '박신지', 10885: '윤명준', 13071: '정철원', 13058: '후랭코프', 14175: '김태근', 12970: '김민혁', 10217: '이용찬', 13248: '진재혁', 10230: '홍상삼', 10221: '이현승', 11084: '백동훈', 12568: '이영하', 11319: '윤수호', 12524: '조수행', 10174: '김재호', 10182: '최주환', 11108: '이흥련', 10305: '허준혁', 12892: '박유연', 13072: '김민규', 12848: '문원', 12852: '최원준', 10882: '변시원', 13076: '박성모', 11220: '박정준', 12893: '백민규', 12850: '박치국', 11207: '김경호', 13269: '신민철', 11159: '이형범', 13268: '김호준', 12607: '정덕현', 12606: '홍성호', 10887: '이태오', 14171: '전루건', 14173: '이교훈', 13266: '계정웅', 14174: '이민혁', 13074: '배창현', 13077: '신현수', 14569: '정현욱', 13078: '정우석', 14205: '김문수', 13270: '안준', 14196: '윤산흠', 14195: '최지원', 11203: '한주성', 14737: '오명진', 14736: '박지훈', 12649: '최용제', 10696: '홍건희', 14571: '안권수', 14575: '플렉센', 12890: '전태준', 13665: '권휘', 12847: '김명신', 11387: '채원후', 13941: '알칸타라', 14570: '장규빈', 12678: '이승진', 10083: '정상호', 12891: '지윤', 14572: '이주엽', 14653: '추종민', 11205: '전용훈', 14652: '전형근', 14738: '양찬열', 14730: '김성민', 14732: '조제영', 14574: '최세창', 14731: '박웅', 14733: '최종인', 14734: '지원근', 14735: '구장익', 14771: '안재석', 14139: '남호', 11198: '박계범', 11087: '강승호', 11181: '핸킨스', 14769: '김동주', 14750: '로켓', 13271: '현도훈', 12544: '유재유', 11300: '박정수', 11213: '양석환', 14751: '미란다', 12605: '고봉재', 14770: '최승용', 14773: '강현구', 14886: '김도경', 12608: '신창희', 14768: '김도윤', 14772: '임태윤', 14836: '이상연', 14832: '강원진', 14838: '박성재', 14833: '김주완', 14840: '양현진', 14834: '안찬호', 14837: '장빈', 14835: '오세훈', 14839: '백종수', 10747: '김지용', 11328: '안승한', 14999: '스탁', 15127: '최지강', 10452: '임창민', 11148: '강진성', 15153: '브랜든', 15099: '이병헌', 15100: '김동준', 15102: '신민철', 15101: '이원재', 15103: '전희범', 15104: '윤태호', 15105: '정유석', 15106: '강동형', 15107: '임준형', 15108: '김시완', 15109: '강산', 15128: '천현재', 15129: '이민석', 12522: '박준영', 15539: '로하스', 10165: '양의지', 13124: '김정우', 15538: '딜런', 14573: '제환유', 15508: '최준호', 15509: '김유성', 15511: '임서준', 15512: '윤준호', 15513: '한충희', 15514: '백승우', 15515: '박민준', 15516: '김문수', 15517: '남율', 15611: '이정원', 15613: '이기석', 13106: '조선명', 15000: '라모스', 16068: '여동건', 16002: '로하스', 16001: '딜런', 16069: '임종성', 12549: '김기연', 16072: '전다민', 15971: '최준호', 15972: '김유성', 16067: '김택연', 15973: '장우진', 16070: '강태완', 15974: '임서준', 15975: '윤준호', 15976: '한충희', 15977: '백승우', 15978: '박민준', 15979: '김문수', 15980: '남율', 16071: '박지호', 16073: '김무빈', 16074: '손율기', 16075: '김태완', 16076: '류현준', 16142: '장원호', 11226: '임병욱', 10863: '한현희', 14130: '박주성', 13095: '배현호', 12905: '김혜성', 12503: '김웅빈', 14216: '정현민', 14214: '김주형', 12859: '이병규', 11224: '김하성', 12992: '브리검', 10866: '박정음', 11149: '신재영', 11126: '조상우', 12987: '김종덕', 10399: '김지수', 10855: '서건창', 10445: '오주원', 10871: '김태훈', 10437: '문성현', 11379: '최원태', 12918: '김성민', 12567: '주효상', 10404: '장영석', 10427: '김상수', 12878: '박성민', 11169: '이상민', 10387: '박동원', 10493: '이택근', 11130: '조성운', 11498: '허정협', 14133: '주성원', 12865: '이승호', 11225: '임지열', 12858: '김재웅', 10868: '김규민', 12620: '김한별', 10722: '윤영삼', 10730: '양현', 13091: '안우진', 12632: '이찬석', 13940: '요키시', 12855: '최규보', 13101: '정동욱', 13288: '샌즈', 13096: '김수환', 10448: '이보근', 13099: '이재승', 13092: '김선기', 11069: '손동욱', 12906: '이정후', 10470: '박병호', 13093: '예진원', 12574: '서의태', 11222: '하영민', 10312: '이지영', 11376: '송성문', 13223: '변상권', 13097: '신효승', 14132: '조영건', 13010: '임규빈', 11531: '김정인', 13094: '추재현', 11377: '송우현', 14211: '박준형', 12997: '이영준', 12854: '양지율', 14212: '이명기', 14480: '김인범', 13100: '조재건', 13098: '조병규', 14218: '김신회', 14213: '김준연', 12683: '김은성', 14217: '김상현', 13196: '노윤상', 14131: '윤정현', 14579: '모터', 14577: '김병휘', 14695: '신준우', 11260: '박준태', 10224: '정대현', 13184: '김 ...
